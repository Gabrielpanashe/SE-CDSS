# %% [markdown]
# # SE-CDSS — Dataset exploration
#
# Use this notebook for exploratory analysis of the UCI Drug Review dataset (`data/raw/`). Run preprocessing and model training from the CLI per `README.md`.

# %%
from pathlib import Path

import pandas as pd

ROOT = Path("..").resolve()
train_path = ROOT / "data" / "raw" / "drugsComTrain_raw.csv"
if train_path.exists():
    df = pd.read_csv(train_path)
    display(df.head())
    print(df.shape)
else:
    print(f"Place raw CSV at {train_path}")
